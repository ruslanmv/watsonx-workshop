# %% [markdown]
# # Lab 2.3: Twin RAG Pipelines - Ollama vs watsonx Comparison 🔬
#
# **Duration**: 60 minutes | **Difficulty**: Intermediate
#
# ## 🎯 What You'll Build
#
# A systematic comparison framework to analyze:
# - **Performance**: Which is faster?
# - **Quality**: Which gives better answers?
# - **Cost**: What are the trade-offs?
#
# **Real-world value**: Learn to make data-driven decisions about RAG architecture!

# %%
# Setup
import time
import pandas as pd
import matplotlib.pyplot as plt
from typing import Dict, List

print('✅ Ready to compare RAG systems!')

# %% [markdown]
# ## Step 1: Build Both RAG Systems
#
# We'll create identical pipelines with Ollama and watsonx.

# %%
# TODO: Set up both RAG systems
# Use code from Labs 2.1 and 2.2

# Sample test documents
test_questions = [
    'What is RAG?',
    'Explain vector databases',
    'What are Granite models?'
]

print(f'Test questions: {len(test_questions)}')

# %% [markdown]
# ## Step 2: Run Comparison Tests

# %%
def compare_rag(question: str) -> Dict:
    '''Run same question through both systems.'''
    # TODO: Implement comparison
    return {
        'question': question,
        'ollama_time': 0.0,
        'watsonx_time': 0.0
    }

results = [compare_rag(q) for q in test_questions]
print('✅ Comparison complete!')

# %% [markdown]
# ## Step 3: Visualize Results

# %%
# Create comparison charts
df = pd.DataFrame(results)
print(df)

# %% [markdown]
# ## 🎯 Conclusions
#
# Based on your results:
# - **Speed**: Which was faster?
# - **Quality**: Which gave better answers?
# - **When to use each**: Document your recommendations
